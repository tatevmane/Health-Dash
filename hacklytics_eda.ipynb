# %%
import pandas as pd

# %%
food = pd.read_csv("/Users/tatevgomtsyan/Independent Projects/FoodAccessResearchAtlasData2019.csv")
obesity = pd.read_csv("/Users/tatevgomtsyan/Downloads/LakeCounty_Health_-6821310239639457742.csv")

# %%
food.head()
# Out:
#    CensusTract    State          County  Urban  Pop2010  OHU2010  \
# 0   1001020100  Alabama  Autauga County      1     1912      693
# 1   1001020200  Alabama  Autauga County      1     2170      743
# 2   1001020300  Alabama  Autauga County      1     3373     1256
# 3   1001020400  Alabama  Autauga County      1     4386     1722
# 4   1001020500  Alabama  Autauga County      1    10766     4082
#
#    GroupQuartersFlag  NUMGQTRS  PCTGQTRS  LILATracts_1And10  ...  \
# 0                  0       0.0      0.00                  0  ...
# 1                  0     181.0      8.34                  1  ...
# 2                  0       0.0      0.00                  0  ...
# 3                  0       0.0      0.00                  0  ...
# 4                  0     181.0      1.68                  0  ...
#
#    TractSeniors  TractWhite  TractBlack  TractAsian  TractNHOPI  TractAIAN  \
# 0         221.0      1622.0       217.0        14.0         0.0       14.0
# ...

# %%
obesity.head()
# Out:
#    OBJECTID        NAME  Obesity   Shape__Area  Shape__Length
# 0         1       Texas     32.4  7.672329e+12   1.540832e+07
# 1         2  California     24.2  5.327809e+12   1.451870e+07
# 2         3    Kentucky     34.6  1.128830e+12   6.346699e+06
# 3         4     Georgia     30.7  1.652980e+12   5.795596e+06
# 4         5   Wisconsin     30.7  1.567816e+12   6.806782e+06

# %%
merged_df = pd.merge(food, obesity, left_on='State',right_on='NAME')
merged_df = merged_df.drop(columns=['NAME', 'Shape__Area', 'Shape__Length'])

# %%
merged_df.head()
# Out:
#    CensusTract    State          County  Urban  Pop2010  OHU2010  \
# 0   1001020100  Alabama  Autauga County      1     1912      693
# 1   1001020200  Alabama  Autauga County      1     2170      743
# 2   1001020300  Alabama  Autauga County      1     3373     1256
# 3   1001020400  Alabama  Autauga County      1     4386     1722
# 4   1001020500  Alabama  Autauga County      1    10766     4082
#
#    GroupQuartersFlag  NUMGQTRS  PCTGQTRS  LILATracts_1And10  ...  TractBlack  \
# 0                  0       0.0      0.00                  0  ...       217.0
# 1                  0     181.0      8.34                  1  ...      1217.0
# 2                  0       0.0      0.00                  0  ...       647.0
# 3                  0       0.0      0.00                  0  ...       193.0
# 4                  0     181.0      1.68                  0  ...      1437.0
#
#    TractAsian  TractNHOPI  TractAIAN  TractOMultir  TractHispanic  TractHUNV  \
# ...

# %%
merged_df.columns.to_list()
# Out:
# ['CensusTract',
#  'State',
#  'County',
#  'Urban',
#  'Pop2010',
#  'OHU2010',
#  'GroupQuartersFlag',
#  'NUMGQTRS',
#  'PCTGQTRS',
#  'LILATracts_1And10',
#  'LILATracts_halfAnd10',
#  'LILATracts_1And20',
#  'LILATracts_Vehicle',
#  'HUNVFlag',
#  'LowIncomeTracts',
#  'PovertyRate',
#  'MedianFamilyIncome',
#  'LA1and10',
#  'LAhalfand10',
#  'LA1and20',
#  'LATracts_half',
#  'LATracts1',
#  'LATracts10',
#  'LATracts20',
#  'LATractsVehicle_20',
#  'LAPOP1_10',
#  'LAPOP05_10',
#  'LAPOP1_20',
#  'LALOWI1_10',
#  'LALOWI05_10',
#  'LALOWI1_20',
#  'lapophalf',
#  'lapophalfshare',
#  'lalowihalf',
#  'lalowihalfshare',
#  'lakidshalf',
#  'lakidshalfshare',
#  'laseniorshalf',
#  'laseniorshalfshare',
#  'lawhitehalf',
#  'lawhitehalfshare',
#  'lablackhalf',
#  'lablackhalfshare',
#  'laasianhalf',
#  'laasianhalfshare',
#  'lanhopihalf',
#  'lanhopihalfshare',
#  'laaianhalf',
#  'laaianhalfshare',
#  'laomultirhalf',
#  'laomultirhalfshare',
#  'lahisphalf',
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

selected_variables = ['Obesity', 'PovertyRate', 'TractBlack', 'MedianFamilyIncome', 'LA1and20']  # Add other variables as needed
data_for_pairplot = merged_df[selected_variables].dropna()

# Create pair plot
sns.pairplot(data_for_pairplot)

# Show plot
plt.show()
# Out:
# /Users/tatevgomtsyan/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# The above pair plot shows the relationship between various variables of interest in the dataset. Noteworthy points: As poverty rate increases, median family income dereases. Obesity and poverty seem to be slightly positively correlated, although there is no clear relationship.

# %%
# Generate summary statistics for the obesity variable
obesity_summary = merged_df['Obesity'].describe()

# Print the summary table
print(obesity_summary)
# Out:
# count    72531.000000
# mean        28.938010
# std          3.641354
# min         20.200000
# 25%         25.600000
# 50%         29.800000
# 75%         31.300000
# max         36.200000
# Name: Obesity, dtype: float64

# %%
# Sort DataFrame by 'Obesity' column in descending order
sorted_df = merged_df.sort_values(by='Obesity', ascending=False)

# Create bar plot of obesity by state
plt.figure(figsize=(12, 6))  # Set the figure size
sns.barplot(data=sorted_df, x='State', y='Obesity', palette='viridis')

# Set plot title and labels
plt.title('Bar Plot of Obesity by State')
plt.xlabel('State')
plt.ylabel('Obesity Rate')

# Rotate x-axis labels for better visibility
plt.xticks(rotation=45)

# Show plot
plt.tight_layout()  # Adjust layout
plt.show()

# %% [markdown]
# Southern states like Louisiana, Mississippi, and Alabama have the highest obesity rates in the country, while more metropolitan or nature-surrounded cities have lower rates.

# %%
# Generate summary statistics for the obesity variable
obesity_summary = merged_df['PovertyRate'].describe()

# Print the summary table
print(obesity_summary)
# Out:
# count    72528.000000
# mean        15.183864
# std         11.919903
# min          0.000000
# 25%          6.500000
# 50%         12.000000
# 75%         20.600000
# max        100.000000
# Name: PovertyRate, dtype: float64

# %%
# Sort DataFrame by 'PovertyRate' column in descending order
poverty = merged_df.sort_values(by='PovertyRate', ascending=False)

# Create bar plot of poverty rate by state
plt.figure(figsize=(12, 6))  # Set the figure size
sns.barplot(data=poverty, x='State', y='PovertyRate')

# Set plot title and labels
plt.title('Bar Plot of Poverty Rate by State')
plt.xlabel('State')
plt.ylabel('Poverty Rate')

# Rotate x-axis labels for better visibility
plt.xticks(rotation=45)

# Show plot
plt.tight_layout()  # Adjust layout
plt.show()

# %% [markdown]
# Indiana has the highest poverty rate, followed by Maryland.

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=merged_df, x='Urban', y='Obesity', palette='coolwarm')

# Set plot title and labels
plt.title('Obesity Rate by Urban/Rural Status')
plt.xlabel('Rural/Urban')
plt.ylabel('Obesity Rate')

# Show plot
plt.tight_layout()
plt.show()

# %% [markdown]
# Obesity rate is not visibly much different in rural vs urban areas. Obesity rate across the US sits around 30%, making it a big public health issue.
